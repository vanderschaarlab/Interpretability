# %% [markdown]
# # Tutorial 2 - SimplEx for Time Series Data
#
# In this tutorial we we create a simplex explainer object and use it to explain a test record. The explainer is then saved to disk and can be given to someone else to view in the Interpretability App. (TODO: add link to app).
#
# We will be explaining the predictions of pytorch convolutional neural net that we have trained and saved separately on an engine noise dataset from IEEE World Congress on Computational Intelligence, 2008. The Interpretability.models module provides a pytorch model for this that is compatible with trained models `state_dict`s available on the Google Drive link below.
#
# ### Import the relevant modules

# %%
# IMPORTS
# Standard
import os
import numpy as np
import pathlib
# Third Party
import torch
# Interpretability
from interpretability.interpretability_models import simplex_explainer
from interpretability.interpretability_models.utils import io
from interpretability.models.recurrent_neural_net import ConvNet

# %% [markdown]
# ### Load the data
# Load the data and split it into the corpus of examples used for explanation and the test examples we will explain. This cell will download the data from the `root_url` and save it to a subdirectory in the folder this notebook is being run.

# %%
# LOADS
def load_forda_data():

    def readucr(filename):
        data = np.loadtxt(filename, delimiter="\t")
        y = data[:, 0]
        x = data[:, 1:]
        return x, y.astype(int)

    root_url = "https://raw.githubusercontent.com/hfawaz/cd-diagram/master/FordA/"

    x_train, y_train = readucr(root_url + "FordA_TRAIN.tsv")
    x_test, y_test = readucr(root_url + "FordA_TEST.tsv")

    x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
    x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))

    idx = np.random.permutation(len(x_train))
    x_train = x_train[idx]
    y_train = y_train[idx]

    y_train[y_train == -1] = 0
    y_test[y_test == -1] = 0

    return x_train, y_train, x_test, y_test


# LOAD data
(
    X_corpus,
    y_corpus,
    X_explain,
    y_explain,
) = load_forda_data()

# %% [markdown]
# ### Download the trained model from Google Drive
#
# You could train your own model using the ConvNet class and load it here, but we have trained one already.
#
# Download the model using this link: https://drive.google.com/file/d/173vniHegUSGmdC6fKCLupynRoxEdz9Ko/view?usp=sharing and save it in a location matching the path `TRAINED_MODEL_STATE_PATH` below. The default is the desktop.
#
# ### Load the model

# %%
## Load the model
model = ConvNet()

def load_trained_model(model, trained_model_state_path):
    model.load_state_dict(torch.load(trained_model_state_path))
    model.eval()
    return model

desktop_path = pathlib.Path.home() / 'Desktop'

TRAINED_MODEL_STATE_PATH = os.path.join(desktop_path, "model_cv1_2.pth")
model = load_trained_model(model, TRAINED_MODEL_STATE_PATH)

# %% [markdown]
# ### Initialize SimplEX
# Initialize the explainer object by passing the predictive model and corpus.

# %%
# Fit SimplEx
corpus_size = 100
# Initialize SimplEX, fit it on test examples
my_explainer = simplex_explainer.SimplexTimeSeriesExplainer(
    model,
    X_corpus,
    y_corpus,
    estimator_type="classifier",
    feature_names=["Engine Noise"],
    corpus_size=corpus_size,
    device="cuda" if torch.cuda.is_available() else "cpu",
)

# %% [markdown]
# ### Fit the explainer
#
# Fit the explainer on the test data. This makes explanations of the test data available in the subsequent step.

# %%
my_explainer.fit(X_explain, y_explain)
# Out:
# Weight Fitting Epoch: 2000/10000 ; Error: 5.86e+06 ; Regulator: 863 ; Reg Factor: 1
# Weight Fitting Epoch: 4000/10000 ; Error: 5.63e+06 ; Regulator: 620 ; Reg Factor: 1
# Weight Fitting Epoch: 6000/10000 ; Error: 5.6e+06 ; Regulator: 598 ; Reg Factor: 1
# Weight Fitting Epoch: 8000/10000 ; Error: 5.59e+06 ; Regulator: 593 ; Reg Factor: 1
# Weight Fitting Epoch: 10000/10000 ; Error: 5.59e+06 ; Regulator: 591 ; Reg Factor: 1

# %% [markdown]
# ### Get the explanation
# Explain any given record in the test set by changing the index, i.

# %%
i = 1
explanation = my_explainer.explain(i, baseline="median")

# %% [markdown]
# ### Plot the explanation
#
# The explanation is plotted as a styled df, in this notebook, but it is also viewable in the browser, if the `return_type` is set to "html".

# %%
# Corpus of patients
my_explainer.summary_plot(
    # rescale_dict=rescale_dict,
    example_importance_threshold=0.08,
    time_steps_to_display=10,
    plot_test=True,
    output_file_prefix="testing",
    open_in_browser=True,
    return_type="styled_df",
)
# Out:
#              Engine Noise
# (t_max) - 9      0.435186
# (t_max) - 8     -0.346502
# (t_max) - 7     -0.924912
# (t_max) - 6     -1.208716
# (t_max) - 5     -1.247996
# (t_max) - 4     -1.139974
# (t_max) - 3     -1.041772
# (t_max) - 2     -1.041772
# (t_max) - 1     -1.159614
# (t_max)         -1.375659
# Corpus Example: 0
# Example Importance: 0.15802191197872162
# <style type="text/css">
# #T_55bfd_row0_col0, #T_55bfd_row0_col2 {
#   background-color: #ffdcdc;
# }
# #T_55bfd_row0_col1 {
#   background-color: #ffe6e6;
# }
# #T_55bfd_row0_col3 {
#   background-color: #ffe2e2;
# }
# #T_55bfd_row0_col4 {
#   background-color: #ffdada;
# }
# #T_55bfd_row0_col5 {
#   background-color: #ffd8d8;
# }
# #T_55bfd_row0_col6 {
#   background-color: #ff9090;
# }
# #T_55bfd_row0_col7 {
#   background-color: #6666ff;
# }
# #T_55bfd_row0_col8 {
#   background-color: #ffa4a4;
# }
# #T_55bfd_row0_col9 {
#   background-color: #ff7e7e;
# }
# </style>
# <table id="T_55bfd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_55bfd_level0_row0" class="row_heading level0 row0" >Engine Noise</th>
#       <td id="T_55bfd_row0_col0" class="data row0 col0" >-0.665776</td>
#       <td id="T_55bfd_row0_col1" class="data row0 col1" >-0.617297</td>
#       <td id="T_55bfd_row0_col2" class="data row0 col2" >-0.422226</td>
#       <td id="T_55bfd_row0_col3" class="data row0 col3" >-0.027928</td>
#       <td id="T_55bfd_row0_col4" class="data row0 col4" >0.512730</td>
#       <td id="T_55bfd_row0_col5" class="data row0 col5" >1.066778</td>
#       <td id="T_55bfd_row0_col6" class="data row0 col6" >1.529639</td>
#       <td id="T_55bfd_row0_col7" class="data row0 col7" >1.760492</td>
#       <td id="T_55bfd_row0_col8" class="data row0 col8" >1.702779</td>
#       <td id="T_55bfd_row0_col9" class="data row0 col9" >1.356499</td>
#     </tr>
#   </tbody>
# </table>
# Corpus Example: 1
# Example Importance: 0.12179539352655411
# <style type="text/css">
# #T_8efc0_row0_col0 {
#   background-color: #fafaff;
# }
# #T_8efc0_row0_col1 {
#   background-color: #dadaff;
# }
# #T_8efc0_row0_col2 {
#   background-color: #ff7e7e;
# }
# #T_8efc0_row0_col3 {
#   background-color: #6666ff;
# }
# #T_8efc0_row0_col4 {
#   background-color: #ffbaba;
# }
# #T_8efc0_row0_col5 {
#   background-color: #fffcfc;
# }
# #T_8efc0_row0_col6 {
#   background-color: #f8f8ff;
# }
# #T_8efc0_row0_col7 {
#   background-color: #fff8f8;
# }
# #T_8efc0_row0_col8 {
#   background-color: #e8e8ff;
# }
# #T_8efc0_row0_col9 {
#   background-color: #ffcccc;
# }
# </style>
# <table id="T_8efc0_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8efc0_level0_row0" class="row_heading level0 row0" >Engine Noise</th>
#       <td id="T_8efc0_row0_col0" class="data row0 col0" >-1.292667</td>
#       <td id="T_8efc0_row0_col1" class="data row0 col1" >-1.337287</td>
#       <td id="T_8efc0_row0_col2" class="data row0 col2" >-1.337287</td>
#       <td id="T_8efc0_row0_col3" class="data row0 col3" >-1.337287</td>
#       <td id="T_8efc0_row0_col4" class="data row0 col4" >-1.359596</td>
#       <td id="T_8efc0_row0_col5" class="data row0 col5" >-1.348442</td>
#       <td id="T_8efc0_row0_col6" class="data row0 col6" >-1.370751</td>
#       <td id="T_8efc0_row0_col7" class="data row0 col7" >-1.381906</td>
#       <td id="T_8efc0_row0_col8" class="data row0 col8" >-1.393061</td>
#       <td id="T_8efc0_row0_col9" class="data row0 col9" >-1.393061</td>
#     </tr>
#   </tbody>
# </table>
# Corpus Example: 2
# Example Importance: 0.12088353931903839
# <style type="text/css">
# #T_9cb7a_row0_col0 {
#   background-color: #bcbcff;
# }
# #T_9cb7a_row0_col1 {
#   background-color: #aeaeff;
# }
# #T_9cb7a_row0_col2 {
#   background-color: #fefeff;
# }
# #T_9cb7a_row0_col3 {
#   background-color: #6666ff;
# }
# #T_9cb7a_row0_col4 {
#   background-color: #babaff;
# }
# #T_9cb7a_row0_col5 {
#   background-color: #9c9cff;
# }
# #T_9cb7a_row0_col6 {
#   background-color: #7a7aff;
# }
# #T_9cb7a_row0_col7 {
#   background-color: #f4f4ff;
# }
# #T_9cb7a_row0_col8 {
#   background-color: #ffb2b2;
# }
# #T_9cb7a_row0_col9 {
#   background-color: #ff7e7e;
# }
# </style>
# <table id="T_9cb7a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cb7a_level0_row0" class="row_heading level0 row0" >Engine Noise</th>
#       <td id="T_9cb7a_row0_col0" class="data row0 col0" >0.647003</td>
#       <td id="T_9cb7a_row0_col1" class="data row0 col1" >-0.009810</td>
#       <td id="T_9cb7a_row0_col2" class="data row0 col2" >-0.780005</td>
#       <td id="T_9cb7a_row0_col3" class="data row0 col3" >-1.279253</td>
#       <td id="T_9cb7a_row0_col4" class="data row0 col4" >-1.217744</td>
#       <td id="T_9cb7a_row0_col5" class="data row0 col5" >-0.537045</td>
#       <td id="T_9cb7a_row0_col6" class="data row0 col6" >0.570117</td>
#       <td id="T_9cb7a_row0_col7" class="data row0 col7" >1.785945</td>
#       <td id="T_9cb7a_row0_col8" class="data row0 col8" >2.729083</td>
#       <td id="T_9cb7a_row0_col9" class="data row0 col9" >3.036628</td>
#     </tr>
#   </tbody>
# </table>
# Corpus Example: 3
# Example Importance: 0.11819148808717728
# <style type="text/css">
# #T_aa1f6_row0_col0 {
#   background-color: #9494ff;
# }
# #T_aa1f6_row0_col1 {
#   background-color: #b2b2ff;
# }
# #T_aa1f6_row0_col2 {
#   background-color: #ffa0a0;
# }
# #T_aa1f6_row0_col3 {
#   background-color: #ececff;
# }
# #T_aa1f6_row0_col4 {
#   background-color: #dadaff;
# }
# #T_aa1f6_row0_col5 {
#   background-color: #ffd0d0;
# }
# #T_aa1f6_row0_col6 {
#   background-color: #6666ff;
# }
# #T_aa1f6_row0_col7 {
#   background-color: #ff7e7e;
# }
# #T_aa1f6_row0_col8 {
#   background-color: #c8c8ff;
# }
# #T_aa1f6_row0_col9 {
#   background-color: #ffcaca;
# }
# </style>
# <table id="T_aa1f6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >0</th>
#       <th class="col_heading level0 col1" >1</th>
#       <th class="col_heading level0 col2" >2</th>
#       <th class="col_heading level0 col3" >3</th>
#       <th class="col_heading level0 col4" >4</th>
#       <th class="col_heading level0 col5" >5</th>
#       <th class="col_heading level0 col6" >6</th>
#       <th class="col_heading level0 col7" >7</th>
#       <th class="col_heading level0 col8" >8</th>
#       <th class="col_heading level0 col9" >9</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_aa1f6_level0_row0" class="row_heading level0 row0" >Engine Noise</th>
#       <td id="T_aa1f6_row0_col0" class="data row0 col0" >-1.672539</td>
#       <td id="T_aa1f6_row0_col1" class="data row0 col1" >-2.083083</td>
#       <td id="T_aa1f6_row0_col2" class="data row0 col2" >-1.864126</td>
#       <td id="T_aa1f6_row0_col3" class="data row0 col3" >-1.088655</td>
#       <td id="T_aa1f6_row0_col4" class="data row0 col4" >0.009778</td>
#       <td id="T_aa1f6_row0_col5" class="data row0 col5" >1.082665</td>
#       <td id="T_aa1f6_row0_col6" class="data row0 col6" >1.830767</td>
#       <td id="T_aa1f6_row0_col7" class="data row0 col7" >2.058847</td>
#       <td id="T_aa1f6_row0_col8" class="data row0 col8" >1.739535</td>
#       <td id="T_aa1f6_row0_col9" class="data row0 col9" >1.046173</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Save the explainer to file
# This file can now be uploaded to the Interpretability Suite app (TODO: add link). This provides a non-programtic interface with which to view the various explanations, allowing you to send the explainer to a colleague who is less fluent in python.

# %%
io.save_explainer(
    my_explainer, "my_new_forda_conv_time_simplex_explainer.p"
)
# Out:
# Saving explainer to: /home/rob/Documents/projects/Interpretability/Notebooks/my_new_forda_conv_time_simplex_explainer.p
