# %% [markdown]
# # Tutorial 1 - SimplEx for Tabular Data
#
# In this tutorial we we create a simplex explainer object and use it to explain a test record. The explainer is then saved to disk and can be given to someone else to view in the Interpretability App. (TODO: add link to app).
#
# We will be explaining the predictions of pytorch multi-layer perceptron that we have trained and saved separately on the iris dataset from sci-kit learn. The Interpretability.models module provides a few pytorch models that are compatible with trained models `state_dict`s available on the Google Drive link below.
#
# ### Import the relevant modules

# %%
# IMPORTS
# Standard
import os
import pathlib

# Third Party
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import torch
import pandas as pd

# Interpretability
from interpretability.interpretability_models import simplex_explainer
from interpretability.interpretability_models.utils import io
from interpretability.models.multilayer_perceptron import IrisMLP # This is the class of the model we have already trained

# %% [markdown]
# ### Load the data
# Load the data and split it into the corpus of examples used for explanation and the test examples we will explain.

# %%
# Load the data
X, y = load_iris(return_X_y=True, as_frame=True)

# Get feature names
feature_names = X.columns.to_list()

# Split the data
X_corpus, X_test, y_corpus, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Download the trained model from Google Drive
#
# You could train your own model using the IrisMLP class and load it here, but we have trained one already.
#
# Download the model using this link: https://drive.google.com/file/d/1MbQX1PYABB4XNO9c_SR-Mo3i6HjU0hB-/view?usp=sharing and save it in a location matching the path `TRAINED_MODEL_STATE_PATH` below. The default is the desktop.
#
# ### Load the model

# %%
## Load the model
model = IrisMLP(n_cont=4, input_feature_num=len(feature_names))

def load_trained_model(model, trained_model_state_path):
    model.load_state_dict(torch.load(trained_model_state_path))
    model.eval()
    return model

desktop_path = pathlib.Path.home() / 'Desktop'

TRAINED_MODEL_STATE_PATH = os.path.join(desktop_path, "model_cv1.pth")
model = load_trained_model(model, TRAINED_MODEL_STATE_PATH)

# %% [markdown]
# ### Initialize SimplEX
# Initialize the explainer object by passing the predictive model and corpus.

# %%
my_explainer = simplex_explainer.SimplexTabluarExplainer(
    model,
    X_corpus,
    y_corpus,
    estimator_type="classifier",
    feature_names=feature_names,
    corpus_size=100,
    device="cpu",
)

# %% [markdown]
# ### Fit the explainer
#
# Fit the explainer on the test data. This makes explanations of the test data available in the subsequent step.

# %%
my_explainer.fit(X_test, y_test, n_epochs=10000)
# Out:
# Weight Fitting Epoch: 2000/10000 ; Error: 400 ; Regulator: 24.3 ; Reg Factor: 1
# Weight Fitting Epoch: 4000/10000 ; Error: 118 ; Regulator: 17.5 ; Reg Factor: 1
# Weight Fitting Epoch: 6000/10000 ; Error: 66.7 ; Regulator: 11.8 ; Reg Factor: 1
# Weight Fitting Epoch: 8000/10000 ; Error: 53.2 ; Regulator: 7.65 ; Reg Factor: 1
# Weight Fitting Epoch: 10000/10000 ; Error: 48.1 ; Regulator: 4 ; Reg Factor: 1

# %% [markdown]
# ### Get the explanation
# Explain any given record in the test set by changing the index, i.

# %%
# Explain
i = 29
explanation = my_explainer.explain(
    i,
    baseline="median",
)

# %% [markdown]
# ### Plot the explanation
#
# The explanation is plotted as a styled df, in this notebook, but it is also viewable in the browser, if the `return_type` is set to "html".

# %%
explain_record_df, display_corpus_df = my_explainer.summary_plot(
    example_importance_threshold=0.000000001,
    output_file_prefix="",
    return_type="styled_df",
    rescaler=scaler,
)
display(explain_record_df)
display(display_corpus_df)
# Out:
#   sepal length (cm) sepal width (cm) petal length (cm) petal width (cm)  \
# 0               5.9              3.0               4.2              1.5
#
#    Test Prediction  Test Label
# 0                0           1
# <style type="text/css">
# #T_90a69_row0_col0, #T_90a69_row0_col3, #T_90a69_row4_col0, #T_90a69_row4_col1, #T_90a69_row8_col1, #T_90a69_row10_col1, #T_90a69_row11_col1, #T_90a69_row14_col1, #T_90a69_row17_col1, #T_90a69_row19_col1, #T_90a69_row24_col1, #T_90a69_row26_col1, #T_90a69_row28_col0, #T_90a69_row31_col1, #T_90a69_row34_col2, #T_90a69_row37_col1, #T_90a69_row38_col1, #T_90a69_row39_col1, #T_90a69_row47_col2, #T_90a69_row47_col3, #T_90a69_row48_col1, #T_90a69_row50_col3, #T_90a69_row51_col3, #T_90a69_row52_col0, #T_90a69_row52_col3, #T_90a69_row53_col1, #T_90a69_row53_col2, #T_90a69_row54_col0, #T_90a69_row54_col3, #T_90a69_row55_col2, #T_90a69_row56_col3, #T_90a69_row57_col3, #T_90a69_row58_col3, #T_90a69_row61_col1, #T_90a69_row62_col1, #T_90a69_row66_col0, #T_90a69_row74_col1, #T_90a69_row99_col0 {
#   background-color: #ececff;
# }
# #T_90a69_row0_col1, #T_90a69_row12_col0, #T_90a69_row14_col0, #T_90a69_row14_col2, #T_90a69_row23_col1, #T_90a69_row30_col2, #T_90a69_row35_col0, #T_90a69_row41_col0, #T_90a69_row41_col1, #T_90a69_row45_col1, #T_90a69_row49_col2, #T_90a69_row56_col1, #T_90a69_row57_col1 {
#   background-color: #f4f4ff;
# }
# #T_90a69_row0_col2, #T_90a69_row4_col2, #T_90a69_row50_col0, #T_90a69_row51_col0, #T_90a69_row55_col0, #T_90a69_row91_col0, #T_90a69_row92_col0 {
#   background-color: #e6e6ff;
# }
# #T_90a69_row0_col4, #T_90a69_row0_col5, #T_90a69_row0_col6, #T_90a69_row1_col4, #T_90a69_row1_col5, #T_90a69_row1_col6, #T_90a69_row2_col4, #T_90a69_row2_col5, #T_90a69_row2_col6, #T_90a69_row3_col4, #T_90a69_row3_col5, #T_90a69_row3_col6, #T_90a69_row4_col4, #T_90a69_row4_col5, #T_90a69_row4_col6, #T_90a69_row5_col4, #T_90a69_row5_col5, #T_90a69
_90a69_row40_col6, #T_90a69_row41_col4, #T_90a69_row41_col5, #T_90a69_row41_col6, #T_90a69_row42_col4, #T_90a69_row42_col5, #T_90a69_row42_col6, #T_90a69_row43_col4, #T_90a69_row43_col5, #T_90a69_row43_col6, #T_90a69_row44_col4, #T_90a69_row44_col5, #T_90a69_row44_col6, #T_90a69_row45_col4, #T_90a69_row45_col5, #T_90a69_row45_col6, #T_90a69_row46_col4, #T_90a69_row46_col5, #T_90a69_row46_col6, #T_90a69_row47_col4, #T_90a69_row47_col5, #T_90a69_row47_col6, #T_90a69_row48_col4, #T_90a69_row48_col5, #T_90a69_row48_col6, #T_90a69_row49_col4, #T_90a69_row49_col5, #T_90a69_row49_col6, #T_90a69_row50_col4, #T_90a69_row50_col5, #T_90a69_row50_col6, #T_90a69_row51_col4, #T_90a69_row51_col5, #T_90a69_row51_col6, #T_90a69_row52_col4, #T_90a69_row52_col5, #T_90a69_row52_col6, #T_90a69_row53_col4, #T_90a69_row53_col5, #T_90a69_row53_col6, #T_90a69_row54_col4, #T_90a69_row54_col5, #T_90a69_row54_col6, #T_90a69_row55_col4, #T_90a69_row55_col5, #T_90a69_row55_col6, #T_90a69_row56_col4, #T_90a69_row56_col5, #T_90a69_row56_col6, #T_90a69_row57_col4, #T_90a69_row57_col5, #T_90a69_row57_col6, #T_90a69_row58_col4, #T_90a69_row58_col5, #T_90a69_row58_col6, #T_90a69_row59_col4, #T_90a69_row59_col5, #T_90a69_row59_col6, #T_90a69_row60_col4, #T_90a69_row60_col5, #T_90a69_row60_col6, #T_90a69_row61_col4, #T_90a69_row61_col5, #T_90a69_row61_col6, #T_90a69_row62_col4, #T_90a69_row62_col5, #T_90a69_row62_col6, #T_90a69_row63_col4, #T_90a69_row63_col5, #T_90a69_row63_col6 ...
#   background-color: #ffffff;
# }
# #T_90a69_row1_col0, #T_90a69_row2_col2, #T_90a69_row6_col1, #T_90a69_row7_col2, #T_90a69_row10_col2, #T_90a69_row13_col2, #T_90a69_row22_col2, #T_90a69_row23_col0, #T_90a69_row35_col2, #T_90a69_row40_col0, #T_90a69_row40_col2, #T_90a69_row44_col0, #T_90a69_row52_col1, #T_90a69_row54_col1, #T_90a69_row58_col1, #T_90a69_row59_col1 {
#   background-color: #fcfcff;
# }
# #T_9

# %% [markdown]
# ### Save the explainer to file
# This file can now be uploaded to the Interpretability Suite app (TODO: add link). This provides a non-programtic interface with which to view the various explanations, allowing you to send the explainer to a colleague who is less fluent in python.

# %%
io.save_explainer(
    my_explainer, "my_new_iris_mlp_simplex_explainer.p"
)
# Out:
# Saving explainer to: /home/rob/Documents/projects/Interpretability/Notebooks/my_new_iris_mlp_simplex_explainer.p
