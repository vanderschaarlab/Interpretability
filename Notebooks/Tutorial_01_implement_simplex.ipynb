# %% [markdown]
# # Tutorial 1 - SimplEx for Tabular Data
#
# In this tutorial we we create a simplex explainer object and use it to explain a test record. The explainer is then saved to disk and can be given to someone else to view in the [Interpretability Suite App](https://vanderschaarlab-demo-interpretabi-interpretability-suite-1uteyn.streamlit.app/).
#
# We will be explaining the predictions of pytorch multi-layer perceptron that we have trained and saved separately on the iris dataset from sci-kit learn. The Interpretability.models module provides a few pytorch models that are compatible with trained models `state_dict`s available on the Google Drive link below.
#
# ### Import the relevant modules

# %%
# IMPORTS
# Standard
import os
import pathlib

# Third Party
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
import torch
import pandas as pd

# Interpretability
from interpretability.interpretability_models import simplex_explainer
from interpretability.interpretability_models.utils import io
from interpretability.models.multilayer_perceptron import IrisMLP # This is the class of the model we have already trained

# %% [markdown]
# ### Load the data
# Load the data and split it into the corpus of examples used for explanation and the test examples we will explain.

# %%
# Load the data
X, y = load_iris(return_X_y=True, as_frame=True)

# Get feature names
feature_names = X.columns.to_list()

# Split the data
X_corpus, X_test, y_corpus, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ### Download the trained model from Google Drive
#
# You could train your own model using the IrisMLP class and load it here, but we have trained one already.
#
# Download the model using this link: https://drive.google.com/file/d/1MbQX1PYABB4XNO9c_SR-Mo3i6HjU0hB-/view?usp=sharing and save it in a location matching the path `TRAINED_MODEL_STATE_PATH` below. The default location is the `"resources/saved_models"` folder inside the root Interpretability directory.
#
# ### Load the model

# %%
## Load the model
model = IrisMLP(n_cont=4, input_feature_num=len(feature_names))

def load_trained_model(model, trained_model_state_path, device='cpu'):
    model.load_state_dict(torch.load(trained_model_state_path, map_location=torch.device(device)))
    model.eval()
    return model

DEVICE = "cpu"

root_path = pathlib.Path.cwd().parents[0]
saved_models_path = root_path / "resources/saved_models"
TRAINED_MODEL_STATE_PATH = saved_models_path / "model_cv1.pth"
model = load_trained_model(model, TRAINED_MODEL_STATE_PATH, device=DEVICE)

# %% [markdown]
# ### Initialize SimplEX
# Initialize the explainer object by passing the predictive model and corpus.

# %%
my_explainer = simplex_explainer.SimplexTabluarExplainer(
    model,
    X_corpus,
    y_corpus,
    estimator_type="classifier",
    feature_names=feature_names,
    corpus_size=100,
    device="cpu",
)
# Out:
# /home/rob/miniconda3/envs/interp/lib/python3.10/site-packages/interpretability/interpretability_models/utils/data.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data = torch.tensor(self.X.iloc[i, :], dtype=torch.float32)

# %% [markdown]
# ### Fit the explainer
#
# Fit the explainer on the test data. This makes explanations of the test data available in the subsequent step.

# %%
my_explainer.fit(X_test, y_test, n_epochs=10000)
# Out:
# /home/rob/miniconda3/envs/interp/lib/python3.10/site-packages/interpretability/interpretability_models/utils/data.py:15: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   data = torch.tensor(self.X.iloc[i, :], dtype=torch.float32)
# Weight Fitting Epoch: 2000/10000 ; Error: 129 ; Regulator: 25.3 ; Reg Factor: 1
# Weight Fitting Epoch: 4000/10000 ; Error: 31.8 ; Regulator: 19.3 ; Reg Factor: 1
# Weight Fitting Epoch: 6000/10000 ; Error: 11 ; Regulator: 10.8 ; Reg Factor: 1
# Weight Fitting Epoch: 8000/10000 ; Error: 5.86 ; Regulator: 5.16 ; Reg Factor: 1
# Weight Fitting Epoch: 10000/10000 ; Error: 4.18 ; Regulator: 1.94 ; Reg Factor: 1

# %% [markdown]
# ### Get the explanation
# Explain any given record in the test set by changing the index, i.

# %%
# Explain
i = 29
explanation = my_explainer.explain(
    i,
    baseline="median",
)

# %% [markdown]
# ### Plot the explanation
#
# The explanation is plotted as a styled df, in this notebook, but it is also viewable in the browser, if the `return_type` is set to "html".

# %%
df1, df2 = my_explainer.summary_plot(
    example_importance_threshold=0.000000001,
    output_file_prefix="",
    return_type="styled_df",
)
display(df1)
display(df2)
# Out:
# /home/rob/miniconda3/envs/interp/lib/python3.10/site-packages/interpretability/interpretability_models/simplex_explainer.py:508: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   importance_df_colors = importance_df_colors.applymap(
#             sepal length (cm) sepal width (cm) petal length (cm)  \
# Test Record               5.5              2.3               4.0
#
#             petal width (cm)  Test Prediction  Test Label
# Test Record              1.3                1           1
# <style type="text/css">
# #T_4bafc_row0_col0, #T_4bafc_row3_col0, #T_4bafc_row25_col0, #T_4bafc_row52_col2, #T_4bafc_row60_col2, #T_4bafc_row83_col0 {
#   background-color: #a6a6ff;
# }
# #T_4bafc_row0_col1, #T_4bafc_row43_col2 {
#   background-color: #ffd2d2;
# }
# #T_4bafc_row0_col2, #T_4bafc_row28_col1, #T_4bafc_row58_col0, #T_4bafc_row58_col2, #T_4bafc_row71_col2, #T_4bafc_row81_col0, #T_4bafc_row81_col2 {
#   background-color: #9494ff;
# }
# #T_4bafc_row0_col3, #T_4bafc_row29_col0, #T_4bafc_row56_col0, #T_4bafc_row69_col0, #T_4bafc_row74_col2, #T_4bafc_row82_col2 {
#   background-color: #9e9eff;
# }
# #T_4bafc_row0_col4, #T_4bafc_row0_col5, #T_4bafc_row0_col6, #T_4bafc_row1_col4, #T_4bafc_row1_col5, #T_4bafc_row1_col6, #T_4bafc_row2_col4, #T_4bafc_row2_col5, #T_4bafc_row2_col6, #T_4bafc_row3_col4, #T_4bafc_row3_col5, #T_4bafc_row3_col6, #T_4bafc_row4_col4, #T_4bafc_row4_col5, #T_4bafc_row4_col6, #T_4bafc_row5_col4, #T_4bafc_row5_col5, #T_4bafc_row5_col6, #T_4bafc_row6_col4, #T_4bafc_row6_col5, #T_4bafc_row6_col6, #T_4bafc_row7_col4, #T_4bafc_row7_col5, #T_4bafc_row7_col6, #T_4bafc_row8_col4, #T_4bafc_row8_col5, #T_4bafc_row8_col6, #T_4bafc_row9_col4, #T_4bafc_row9_col5, #T_4bafc_row9_col6, #T_4bafc_row10_col4, #T_4bafc_row10_col5, #T_4bafc_row10_col6, #T_4bafc_row11_col4, #T_4bafc_row11_col5, #T_4bafc_row11_col6, #T_4bafc_row12_col4, #T_4bafc_row12_col5, #T_4bafc_row12_col6, #T_4bafc_row13_col4, #T_4bafc_row13_col5, #T_4bafc_row13_col6, #T_4bafc_row14_col4, #T_4bafc_row14_col5, #T_4bafc_row14_col6, #T_4bafc_row15_col4, #T_4bafc_row15_col5, #T_4bafc_row15_col6, #T_4bafc_row16_col4, #T_4bafc_row16_col5, #T_4bafc_row16_col6, #T_4bafc_row17_col4, #T_4bafc_row17_col5, #T_4bafc_row17_col6, #T_4bafc_row18_col4, #T_4bafc_row18_col5, #T_4bafc_row18_col6, #T_4bafc_row19_col4, #T_4bafc_row19_col5, #T_4bafc_row19_col6, #T_4bafc_row20_col4, #T_4bafc_row20_col5, #T_4bafc_row20_col6, #T_4bafc_row21_col4, #T_4bafc_row21_col5, #T_4bafc_row21_col6, #T_4bafc_row22_col4, #T_4bafc_row22_col5, #T_4bafc_row22_col6, #T_4bafc_row23_col4, #T_4bafc_row23_col5, #T_4bafc_row23_col6, #T_4bafc_row24_col4, #T_4bafc_row24_col5, #T_4bafc_row24_col6, #T_4bafc_row25_col4, #T_4bafc_row25_col5, #T_4bafc_row25_col6, #T_4bafc_row26_col4, #T_4bafc_row26_col5, #T_4bafc_row26_col6, #T_4bafc_row27_col4, #T_4bafc_row27_col5, #T_4bafc_row27_col6, #T_4bafc_row28_col4, #T_4bafc_row28_col5, #T_4bafc_row28_col6, #T_4bafc_row29_col4, #T_4bafc_row29_col5, #T_4bafc_row29_col6, #T_4bafc_row30_col4, #T_4bafc_row30_col5, #T_4bafc_row30_col6, #T_4bafc_row31_col4, #T_4bafc_row31_col5, #T_4bafc_row31_col6, #T_4bafc_row32_col4, #T_4bafc_row32_col5, #T_4bafc_row32_col6, #T_4bafc_row33_col4, #T_4bafc_row33_col5, #T_4bafc_row33_col6, #T_4bafc_row34_col4, #T_4bafc_row34_col5, #T_4bafc_row34_col6, #T_4bafc_row35_col4, #T_4bafc_row35_col5, #T_4bafc_row35_col6, #T_4bafc_row36_col4, #T_4bafc_row36_col5, #T_4bafc_row36_col6, #T_4bafc_row37_col4, #T_4bafc_row37_col5, #T_4bafc_row37_col6, #T_4bafc_row38_col4, #T_4bafc_row38_col5, #T_4bafc_row38_col6, #T_4bafc_row39_col4, #T_4bafc_row39_col5, #T_4bafc_row39_col6, #T_4bafc_row40_col4, #T_4bafc_row40_col5, #T_4bafc_row40_col6, #T_4bafc_row41_col4, #T_4bafc_row41_col5, #T_4bafc_row41_col6, #T_4bafc_row42_col4, #T_4bafc_row42_col5, #T_4bafc_row42_col6, #T_4bafc_row43_col4, #T_4bafc_row43_col5, #T_4bafc_row43_col6, #T_4bafc_row44_col4, #T_4bafc_row44_col5, #T_4bafc_row44_col6, #T_4bafc_row45_col4, #T_4bafc_row45_col5, #T_4bafc_row45_col6, #T_4bafc_row46_col4, #T_4bafc_row46_col5, #T_4bafc_row46_col6, #T_4bafc_row47_col4, #T_4bafc_row47_col5, #T_4bafc_row47_col6, #T_4bafc_row48_col4, #T_4bafc_row48_col5, #T_4bafc_row48_col6, #T_4bafc_row49_col4, #T_4bafc_row49_col5, #T_4bafc_row49_col6, #T_4bafc_row50_col4, #T_4bafc_row50_col5, #T_4bafc_row50_col6, #T_4bafc_row51_col4, #T_4bafc_row51_col5, #T_4bafc_row51_col6, #T_4bafc_row52_col4, #T_4bafc_row52_col5, #T_4bafc_row52_col6, #T_4bafc_row53_col4, #T_4bafc_row53_col5, #T_4bafc_row53_col6, #T_4bafc_row54_col4, #T_4bafc_row54_col5, #T_4bafc_row54_col6, #T_4bafc_row55_col4, #T_4bafc_row55_col5, #T_4bafc_row55_col6, #T_4bafc_row56_col4, #T_4bafc_row56_col5, #T_4bafc_row56_col6, #T_4bafc_row57_col4, #T_4bafc_row57_col5, #T_4bafc_row57_col6, #T_4bafc_row58_col4, #T_4bafc_row58_col5, #T_4bafc_row58_col6, #T_4bafc_row59_col4, #T_4bafc_row59_col5, #T_4bafc_row59_col6, #T_4bafc_row60_col4, #T_4bafc_row60_col5, #T_4bafc_row60_col6, #T_4bafc_row61_col4, #T_4bafc_row61_col5, #T_4bafc_row61_col6, #T_4bafc_row62_col4, #T_4bafc_row62_col5, #T_4bafc_row62_col6, #T_4bafc_row63_col4, #T_4bafc_row63_col5, #T_4bafc_row63_col6 ...
#   background-color: #ffffff;
# }
# #T_4bafc_row1_col0, #T_4bafc_row1_col2, #T_4bafc_row8_col0, #T_4bafc_row11_col0, #T_4bafc_row15_col3, #T_4bafc_row17_col3, #T_4bafc_row20_col0, #T_4bafc_row34_col0, #T_4bafc_row35_col0, #T_4bafc_row68_col3 {
#   background-color: #b0b0ff;
# }
# #T_4bafc_row1_col1, #T_4bafc_row91_col3, #T_4bafc_row96_col3 {
#   background-color: #ffb0b0;
# }
# #T_4bafc_row1_col3, #T_4bafc_row5_col0, #T_4bafc_row6_col3, #T_4bafc_row9_col3, #T_4bafc_row10_col3, #T_4bafc_row12_col2, #T_4bafc_row12_col3, #T_4bafc_row14_col2, #T_4bafc_row14_col3, #T_4bafc_row15_col1, #T_4bafc_row20_col1, #T_4bafc_row23_col0, #T_4bafc_row23_col1, #T_4bafc_row25_col1, #T_4bafc_row25_col3, #T_4bafc_row26_col1, #T_4bafc_row30_col0, #T_4bafc_row32_col1, #T_4bafc_row33_col1, #T_4bafc_row36_col0, #T_4bafc_row37_col1, #T_4bafc_row39_col0, #T_4bafc_row40_col0, #T_4bafc_row41_col1, #T_4bafc_row46_col1, #T_4bafc_row48_col0, #T_4bafc_row51_col2, #T_4bafc_row52_col3, #T_4bafc_row53_col1, #T_4bafc_row55_col0, #T_4bafc_row55_col2, #T_4bafc_row57_col1, #T_4bafc_row66_col1, #T_4bafc_row72_col1, #T_4bafc_row77_col1, #T_4bafc_row88_col1, #T_4bafc_row89_col1, #T_4

# %% [markdown]
# ### Save the explainer to file
# This file can now be uploaded to the [Interpretability Suite App](https://vanderschaarlab-demo-interpretabi-interpretability-suite-1uteyn.streamlit.app/). This provides a non-programtic interface with which to view the various explanations, allowing you to send the explainer to a colleague who is less fluent in python.

# %%
io.save_explainer(
    my_explainer, "my_new_iris_mlp_simplex_explainer.p"
)
# Out:
# Saving explainer to: /home/rob/Documents/projects/Interpretability/Notebooks/my_new_iris_mlp_simplex_explainer.p
